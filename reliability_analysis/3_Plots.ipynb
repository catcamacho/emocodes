# %%
from emocodes import CodeTimeSeries

cts = CodeTimeSeries(sampling_rate=10)
cts.proc_codes_file(codes_file='/Users/catcamacho/Box/CCP/EmoCodes_project/reliability_data/raw/AHKJS1E2_subjective_character_codes_JULIEN_DB.csv', 
                    video_file='/Users/catcamacho/Box/CCP/EmoCodes_project/reliability_data/episodes/AHKJ_S1E2.mp4')

# %%
import matplotlib.pyplot as plt
from pandas import read_csv

preproc_dir = '/Users/catcamacho/Box/CCP/EmoCodes_project/reliability_data/processed/AHKJ_S1E2/'
obj_codes = read_csv(preproc_dir + 'objective_codes_timeseries_DB_20210316-114734.csv', index_col=0)
obj_codes.index = obj_codes.index/1000
subjnc_codes = read_csv(preproc_dir + 'subjective_noncharacter_codes_timeseries_DB_20210305-100949.csv', index_col=0)
subjnc_codes.index = subjnc_codes.index/1000
subjchar_codes = read_csv(preproc_dir + 'subjective_character_codes_timeseries_Julien_DB_20210317-105559.csv', index_col=0)
subjchar_codes.index = subjchar_codes.index/1000
print(obj_codes.columns)
print(subjnc_codes.columns)
print(subjchar_codes.columns)
# Out:
# Index(['closeup', 'collective', 'has_body', 'has_faces', 'has_words',
#        'interacting_nonverbal', 'interacting_verbal', 'num_chars',
#        'phys_pain_object', 'phys_pain_other', 'scenenum', 'setting',
#        'time_of_day'],
#       dtype='object')
# Index(['audio_intensity', 'audio_valence_negative', 'audio_valence_positive',
#        'visual_intensity', 'visual_valence_negative',
#        'visual_valence_positive'],
#       dtype='object')
# Index(['c_anger_body', 'c_anger_face', 'c_anger_verbal', 'c_comp_body',
#        'c_comp_face', 'c_comp_verbal', 'c_disgust_body', 'c_disgust_face',
#        'c_disgust_verbal', 'c_excite_body', 'c_excite_face', 'c_excite_verbal',
#        'c_fear_body', 'c_fear_face', 'c_fear_verbal', 'c_happy_body',
#        'c_happy_face', 'c_happy_verbal', 'c_hope_body', 'c_hope_face',
#        'c_hope_verbal', 'c_othneg_body', 'c_othneg_face', 'c_othneg_verbal',
#        'c_othpos_body', 'c_othpos_face', 'c_othpos_verbal', 'c_sad_body',
#        'c_sad_face', 'c_sad_verbal', 'c_shame_body', 'c_shame_face',
#        'c_shame_verbal', 'c_surprise_body', 'c_surprise_face',
#        'c_surprise_verbal', 'char_arousal', 'char_valence_negative',
#        'char_valence_positive', 'd_audience', 'd_other', 'd_other_name',
#        'd_self', 'on_screen'],
#       dtype='object')

# %%
# Objective codes exemplar
plt.figure()
obj_codes.plot(y='has_faces',kind='line',figsize=(6,2), legend=None, title='has_faces', xlabel='Time (seconds)', xlim=(0,obj_codes.index[-1]))
plt.tight_layout()
plt.savefig('obj_codes_exemplar.svg')
plt.show()
plt.close()

# %%
# Subjective Noncharacter codes exemplar
plt.figure()
subjnc_codes.plot(y='visual_valence_negative',kind='line',figsize=(6,2), legend=None, title='visual_valence_negative', xlabel='Time (seconds)', xlim=(0,subjnc_codes.index[-1]))
plt.tight_layout()
plt.savefig('subjnc_codes_exemplar.svg')
plt.show()
plt.close()

# %%
# Subjective Character codes exemplar
plt.figure()
subjchar_codes.plot(y='c_happy_face',kind='line',figsize=(6,2), legend=None, title='c_happy_face', xlabel='Time (seconds)', xlim=(0,subjchar_codes.index[-1]))
plt.tight_layout()
plt.savefig('subjchar_codes_exemplar.svg')
plt.show()
plt.close()
